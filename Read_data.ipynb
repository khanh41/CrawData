# %% [markdown]
# # Get data from cloud database DB2 (IBM CLOUD)
# ---

# %% [markdown]
# ### Install library

# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# !pip install ibm_db

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ---
# ### Connect to database

# %%
# %sql ibm_db_sa://xbr09096:q3p%2Bg7szbpg06pm7@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Out:
# 'Connected: xbr09096@BLUDB'

# %% [markdown]
# ---
# ### Code anything you want to show

# %%
# %sql select * from Books limit 5
# Out:
#  * ibm_db_sa://xbr09096:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(10925109, 'https://www.goodreads.com//book/show/10925109-cho-t-i-xin-m-t-v-i-tu-i-th', 'Cho Tôi Xin Một Vé Đi Tuổi Thơ', 'Nguyễn Nhật Ánh', 4.16, 'Truyện Cho tôi xin một vé đi tuổi thơ là sáng tác mới nhất của nhà văn Nguyễn Nhật Ánh. Nhà văn mời người đọc lên chuyến tàu quay ngược trở lại thăm  ... (219 characters truncated) ... lo lắng rồi thở phào. Không chỉ thích hợp với người đọc trẻ, cuốn sách còn có thể hấp dẫn và thực sự có ích cho người lớn trong quan hệ với con mình.'),
# ...

# %%
# %sql select distinct id_book,title_book from Books
# Out:
#  * ibm_db_sa://xbr09096:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(10925109, 'Cho Tôi Xin Một Vé Đi Tuổi Thơ'),
#  (11273677, 'Mắt Biếc'),
#  (10433999, 'Tôi Thấy Hoa Vàng Trên Cỏ Xanh'),
#  (10428411, 'Cô Gái Đến Từ Hôm Qua'),
#  (10925246, 'Tôi Là Bêtô'),
#  (14624837, 'Có Hai Con Mèo Ngồi Bên Cửa Sổ'),
#  (10419181, 'Còn Chút Gì Để Nhớ'),
#  (32068852, 'Ngày Xưa Có Một Chuyện Tình'),
#  (18139866, 'Ngồi Khóc Trên Cây'),
#  (12376409, 'Bàn Có Năm Chỗ Ngồi'),
#  (25072779, 'Bảy Bước Tới Mùa Hè'),
#  (12079188, 'Quán Gò Đi Lên'),
#  (9047825, 'Đi Qua Hoa Cúc'),
#  (10925338, 'Đảo Mộng Mơ'),
#  (17826150, 'Kính vạn hoa (toàn tập)'),
#  (36989101, 'Cây Chuối Non Đi Giày Xanh'),
#  (28961874, 'Con Chó Nhỏ Mang Giỏ Hoa Hồng'),
#  (12966230, 'Trại Hoa Vàng'),
#  (12948705, 'Bồ câu không đưa thư'),
#  (12800840, 'Lá nằm trong lá'),
#  (12456458, 'Hạ đỏ'),
#  (42448945, 'Cảm Ơn Người Lớn'),
#  (11246025, 'Thằng Quỷ Nhỏ'),
# ...

# %% [markdown]
# ## Join Books table and Reviews_Book table
# columns: Title book, author book, review_content, rate

# %%
id_book_to_show = 10925246 # Tôi là beto

# %sql select B.Title_Book,B.Author_Book,R.Review_Content,R.Rate from Books B join Reviews_Book R on B.ID_BOOK = R.ID_BOOK where B.ID_Book = $id_book_to_show
# Out:
#  * ibm_db_sa://xbr09096:***@dashdb-txn-sbox-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Tôi Là Bêtô', 'Nguyễn Nhật Ánh', '"Bạn thấy chưa, càng lớn tuổi, con người ta càng ít nói đi. Họ nghĩ nhiều hơn"---"Các bậc có tuổi thường nghĩ chán rồi mới làm. Có khi nghĩ chán rồi  ... (508 characters truncated) ... ũng thế thôi, có những chuyện bạn đinh ninh chỉ có một mình bạn biết nhưng sự thực thì bạn không phải là người nắm giữ chìa khóa bí mật của cuộc sống', 4),
#  ('Tôi Là Bêtô', 'Nguyễn Nhật Ánh', 'Quyển xuất sắc nhất viết về chuyện chó mèo mà mình từng đọc là Nơi trú ẩn của Kathi Appelt, nhưng so với quyển ấy thì Tôi là Bê Tô lại mang đến một c ... (521 characters truncated) ...  được, phải không nào?!?P.S: mặc dù NNA viết rất là khinh khi các bạn mèo của mình, nhưng mình vẫn ko thể đánh giá quyển này thấp đi được. Thế đấy!!!', 5),
# ...
